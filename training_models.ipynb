# %%
from sklearn import tree
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
column_names = np.array(["age", "workclass", "fnlwgt", "education", "education-num", "marital-status", "occupation","relationship", "race", "sex", "capital-gain", "capital-loss", "hours-pr-week", "native-country", "income"])
catagorical = np.array(["workclass", "fnlwgt", "education", "education-num", "marital-status", "occupation","relationship", "race", "sex", "native-country"])
data = pd.read_csv('data/adult.data', header=None, names=column_names)
data = pd.get_dummies(data, columns=catagorical)

X = data.drop(columns=["income"])
y = data["income"]
#X.values,y.values

# %%
X.values,y.values

# %%
#decition tree
criterion = "gini" # kunne også være "entropy"
dtc = tree.DecisionTreeClassifier(criterion=criterion, min_samples_split=2)
dtc = dtc.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 4
#       2 criterion = "gini" # kunne også være "entropy"
#       3 dtc = tree.DecisionTreeClassifier(criterion=criterion, min_samples_split=2)
# ----> 4 dtc = dtc.fit(X, y)
#
# File c:\Users\katin\Miniconda3\envs\IntelligentSystems\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\katin\Miniconda3\envs\IntelligentSystems\Lib\site-packages\sklearn\tree\_classes.py:1027, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
# ...
